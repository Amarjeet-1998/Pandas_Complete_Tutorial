# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarjeet-1998/Pandas_Complete_Tutorial/blob/main/Pandas%20day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__ # to print the installed version pandas
# Out:
# '1.3.5'

# %%
obj = pd.Series([1, "John", 3.5, "Hey"])
obj
# Out:
# 0       1
# 1    John
# 2     3.5
# 3     Hey
# dtype: object

# %%
obj[0]
# Out:
# 1

# %%
obj.values
# Out:
# array([1, 'John', 3.5, 'Hey'], dtype=object)

# %%
obj2 = pd.Series([1,"john",3.5,"hey"], index =["a","b","c","d"])

# %%
obj2
# Out:
# a       1
# b    john
# c     3.5
# d     hey
# dtype: object

# %%
obj2["b"]
# Out:
# 'john'

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
score = {"jane": 90, "bill":80,"elon": 85, "Tom": 75, "Tim": 95}
names = pd.Series(score) # convert to series
names
# Out:
# jane    90
# bill    80
# elon    85
# Tom     75
# Tim     95
# dtype: int64

# %%
names["Tim"]
# Out:
# 95

# %%
names[names>=85]
# Out:
# jane    90
# elon    85
# Tim     95
# dtype: int64

# %%
names["Tom"]=60
names
# Out:
# jane    90
# bill    80
# elon    85
# Tom     60
# Tim     95
# dtype: int64

# %%
names[names<=80]=83
names
# Out:
# jane    90
# bill    83
# elon    85
# Tom     83
# Tim     95
# dtype: int64

# %%
"Tom" in names
# Out:
# True

# %%
"can" in names
# Out:
# False

# %%
names/10
# Out:
# jane    9.0
# bill    8.3
# elon    8.5
# Tom     8.3
# Tim     9.5
# dtype: float64

# %%
names**2
# Out:
# jane    8100
# bill    6889
# elon    7225
# Tom     6889
# Tim     9025
# dtype: int64

# %%
names.isnull()
# Out:
# jane    False
# bill    False
# elon    False
# Tom     False
# Tim     False
# dtype: bool

# %% [markdown]
# # Working with series Data Structure

# %%
import pandas as pd

# %%
games = pd.read_csv("/content/vgsalesGlobale.csv")

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
games.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.Genre.describe()
# Out:
# count      16598
# unique        12
# top       Action
# freq        3316
# Name: Genre, dtype: object

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts(normalize=True)
# Out:
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: Genre, dtype: float64

# %%
type(games.Genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
games.Genre.value_counts().head()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Name: Genre, dtype: int64

# %%
games.Genre.unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
games.Genre.nunique()
# Out:
# 12

# %%
pd.crosstab(games.Genre, games.Year)
# Out:
# Year          1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  1987.0  \
# Genre
# Action             1      25      18       7       1       2       6       2
# Adventure          0       0       0       1       0       0       0       1
# Fighting           1       0       0       0       0       1       0       2
# Misc               4       0       1       1       1       0       0       0
# Platform           0       3       5       5       1       4       6       2
# Puzzle             0       2       3       1       3       4       0       0
# Racing             0       1       2       0       3       0       1       0
# Role-Playing       0       0       0       0       0       0       1       3
# Shooter            2      10       5       1       3       1       4       2
# Simulation         0       1       0       0       0       1       0       0
# Sports             1       4       2       1       2       1       3       4
# Strategy           0       0       0       0       0       0       0       0
#
# Year          1988.0  1989.0  ...  2009.0  2010.0  2011.0  2012.0  2013.0  \
# Genre                         ...
# Action             2       2  ...     272     226     239     266     148
# Adventure          0       0  ...     141     154     108      58      60
# Fighting           0       0  ...      53      40      50      29      20
# Misc               0       1  ...     207     201     184      38      42
# Platform           4       3  ...      29      31      37      12      37
# Puzzle             1       5  ...      79      45      43      11       3
# Racing             1       0  ...      84      57      65      30      16
# Role-Playing       3       2  ...     103     103      95      78      71
# Shooter            1       1  ...      91      81      94      48      59
# Simulation         1       0  ...     123      82      56      18      18
# Sports             2       3  ...     184     186     122      54      53
# Strategy           0       0  ...      65      53      46      15      19
#
# Year          2014.0  2015.0  2016.0  2017.0  2020.0
# Genre
# Action           186     255     119       1       0
# Adventure         75      54      34       0       0
# Fighting          23      21      14       0       0
# Misc              41      39      18       0       0
# Platform          10      14      10       0       0
# Puzzle             8       6       0       0       0
# Racing            27      19      20       0       0
# Role-Playing      91      78      40       2       0
# Shooter           47      34      32       0       0
# Simulation        11      15       9       0       1
# Sports            55      62      38       0       0
# Strategy           8      17      10       0       0
#
# [12 rows x 39 columns]

# %%
games.Global_Sales.describe()
# Out:
# count    16598.000000
# mean         0.537441
# std          1.555028
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.740000
# Name: Global_Sales, dtype: float64

# %%
games.Global_Sales.mean()
# Out:
# 0.5374406555006628

# %%
games.Global_Sales.value_counts()
# Out:
# 0.02    1071
# 0.03     811
# 0.04     645
# 0.05     632
# 0.01     618
#         ...
# 5.01       1
# 5.05       1
# 5.07       1
# 5.11       1
# 3.16       1
# Name: Global_Sales, Length: 623, dtype: int64

# %%
games.Year.plot(kind="hist")

# %%
games.Genre.value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
games.Genre.value_counts().plot(kind="bar")

# %% [markdown]
# # what is DataFrame?

# %%
import pandas as pd

# %%
data = {"name": ["Bill","Tom","Tim","Alex","pandey","sharma","singh","Neha","gouri"],
        "score": [90,80,79,90,70,67,89,67,58],
        "sport": ["wrestling","boxing","gulf","kabbadi","Cricket","baseball","chess","hockey","Badminton"],
        "sex": ["M","M","M","M","M","M","M","F","F"]}

# %%
data
# Out:
# {'name': ['Bill',
#   'Tom',
#   'Tim',
#   'Alex',
#   'pandey',
#   'sharma',
#   'singh',
#   'Neha',
#   'gouri'],
#  'score': [90, 80, 79, 90, 70, 67, 89, 67, 58],
#  'sport': ['wrestling',
#   'boxing',
#   'gulf',
#   'kabbadi',
#   'Cricket',
#   'baseball',
#   'chess',
#   'hockey',
#   'Badminton'],
#  'sex': ['M', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'F']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  score      sport sex
# 0    Bill     90  wrestling   M
# 1     Tom     80     boxing   M
# 2     Tim     79       gulf   M
# 3    Alex     90    kabbadi   M
# 4  pandey     70    Cricket   M
# 5  sharma     67   baseball   M
# 6   singh     89      chess   M
# 7    Neha     67     hockey   F
# 8   gouri     58  Badminton   F

# %%
df = pd.DataFrame(data,columns=["name","sport","sex","score"])
df
# Out:
#      name      sport sex  score
# 0    Bill  wrestling   M     90
# 1     Tom     boxing   M     80
# 2     Tim       gulf   M     79
# 3    Alex    kabbadi   M     90
# 4  pandey    Cricket   M     70
# 5  sharma   baseball   M     67
# 6   singh      chess   M     89
# 7    Neha     hockey   F     67
# 8   gouri  Badminton   F     58

# %%
df.head()
# Out:
#      name      sport sex  score
# 0    Bill  wrestling   M     90
# 1     Tom     boxing   M     80
# 2     Tim       gulf   M     79
# 3    Alex    kabbadi   M     90
# 4  pandey    Cricket   M     70

# %%
df.tail()
# Out:
#      name      sport sex  score
# 4  pandey    Cricket   M     70
# 5  sharma   baseball   M     67
# 6   singh      chess   M     89
# 7    Neha     hockey   F     67
# 8   gouri  Badminton   F     58

# %%
df.head(2)
# Out:
#    name      sport sex  score
# 0  Bill  wrestling   M     90
# 1   Tom     boxing   M     80

# %%
df.tail(3)
# Out:
#     name      sport sex  score
# 6  singh      chess   M     89
# 7   Neha     hockey   F     67
# 8  gouri  Badminton   F     58

# %%
df=pd.DataFrame(data,columns=["name","sport","gender","score","age"])
df
# Out:
#      name      sport gender  score  age
# 0    Bill  wrestling    NaN     90  NaN
# 1     Tom     boxing    NaN     80  NaN
# 2     Tim       gulf    NaN     79  NaN
# 3    Alex    kabbadi    NaN     90  NaN
# 4  pandey    Cricket    NaN     70  NaN
# 5  sharma   baseball    NaN     67  NaN
# 6   singh      chess    NaN     89  NaN
# 7    Neha     hockey    NaN     67  NaN
# 8   gouri  Badminton    NaN     58  NaN

# %%
df=pd.DataFrame(data, columns=["name", "sport","gender","score","age"],
                index=["one","two","three","four","five","six","seven","eight","nine"])

# %%
df
# Out:
#          name      sport gender  score  age
# one      Bill  wrestling    NaN     90  NaN
# two       Tom     boxing    NaN     80  NaN
# three     Tim       gulf    NaN     79  NaN
# four     Alex    kabbadi    NaN     90  NaN
# five   pandey    Cricket    NaN     70  NaN
# six    sharma   baseball    NaN     67  NaN
# seven   singh      chess    NaN     89  NaN
# eight    Neha     hockey    NaN     67  NaN
# nine    gouri  Badminton    NaN     58  NaN

# %%
df["sport"]
# Out:
# one      wrestling
# two         boxing
# three         gulf
# four       kabbadi
# five       Cricket
# six       baseball
# seven        chess
# eight       hockey
# nine     Badminton
# Name: sport, dtype: object

# %%
my_columns=["name","sport"]
df[my_columns]
# Out:
#          name      sport
# one      Bill  wrestling
# two       Tom     boxing
# three     Tim       gulf
# four     Alex    kabbadi
# five   pandey    Cricket
# six    sharma   baseball
# seven   singh      chess
# eight    Neha     hockey
# nine    gouri  Badminton

# %%
df.sport
# Out:
# one      wrestling
# two         boxing
# three         gulf
# four       kabbadi
# five       Cricket
# six       baseball
# seven        chess
# eight       hockey
# nine     Badminton
# Name: sport, dtype: object

# %%
df.loc[["one"]]
# Out:
#      name      sport gender  score  age
# one  Bill  wrestling    NaN     90  NaN

# %%
df.loc[["one","two"]]
# Out:
#      name      sport gender  score  age
# one  Bill  wrestling    NaN     90  NaN
# two   Tom     boxing    NaN     80  NaN

# %%
df["age"]=18

# %%
df
# Out:
#          name      sport gender  score  age
# one      Bill  wrestling    NaN     90   18
# two       Tom     boxing    NaN     80   18
# three     Tim       gulf    NaN     79   18
# four     Alex    kabbadi    NaN     90   18
# five   pandey    Cricket    NaN     70   18
# six    sharma   baseball    NaN     67   18
# seven   singh      chess    NaN     89   18
# eight    Neha     hockey    NaN     67   18
# nine    gouri  Badminton    NaN     58   18

# %%
df= pd.DataFrame(data,columns=["name","sport","gender","score","age"],
                index=["one","two","three","four","five","six","seven","eight","Nine"])
values=[18,19,39,21,21,31,18,17,12]
df["age"]=values
df
# Out:
#          name      sport gender  score  age
# one      Bill  wrestling    NaN     90   18
# two       Tom     boxing    NaN     80   19
# three     Tim       gulf    NaN     79   39
# four     Alex    kabbadi    NaN     90   21
# five   pandey    Cricket    NaN     70   21
# six    sharma   baseball    NaN     67   31
# seven   singh      chess    NaN     89   18
# eight    Neha     hockey    NaN     67   17
# Nine    gouri  Badminton    NaN     58   12

# %%
df["pass"]=df.score>=70

# %%
df
# Out:
#          name      sport gender  score  age   pass
# one      Bill  wrestling    NaN     90   18   True
# two       Tom     boxing    NaN     80   19   True
# three     Tim       gulf    NaN     79   39   True
# four     Alex    kabbadi    NaN     90   21   True
# five   pandey    Cricket    NaN     70   21   True
# six    sharma   baseball    NaN     67   31  False
# seven   singh      chess    NaN     89   18   True
# eight    Neha     hockey    NaN     67   17  False
# Nine    gouri  Badminton    NaN     58   12  False

# %%
del df["pass"]
df
# Out:
#          name      sport gender  score  age
# one      Bill  wrestling    NaN     90   18
# two       Tom     boxing    NaN     80   19
# three     Tim       gulf    NaN     79   39
# four     Alex    kabbadi    NaN     90   21
# five   pandey    Cricket    NaN     70   21
# six    sharma   baseball    NaN     67   31
# seven   singh      chess    NaN     89   18
# eight    Neha     hockey    NaN     67   17
# Nine    gouri  Badminton    NaN     58   12

# %%
scores={"Math":{"A":85,"B":90,"C":95}, "Physics":{"A":90,"B":80,"C":76}}

# %%
scores_df = pd.DataFrame(scores)
scores_df
# Out:
#    Math  Physics
# A    85       90
# B    90       80
# C    95       76

# %%
scores_df.T
# Out:
#           A   B   C
# Math     85  90  95
# Physics  90  80  76

# %%
scores_df.index.name="name"
scores_df.columns.name="lesson"

# %%
scores_df
# Out:
# lesson  Math  Physics
# name
# A         85       90
# B         90       80
# C         95       76

# %%
scores_df.values
# Out:
# array([[85, 90],
#        [90, 80],
#        [95, 76]])

# %%
scores_index=scores_df.index

# %%
scores_index[1]="Jack"
score_index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-ead87b076e4b> in <module>
# ----> 1 scores_index[1]="Jack"
#       2 score_index
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4583     @final
#    4584     def __setitem__(self, key, value):
# -> 4585         raise TypeError("Index does not support mutable operations")
#    4586
#    4587     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# # Indexing & Selecting & Filtering in Pandas

# %%
import pandas as pd
import numpy as np
